# %%
import duckdb

# %%
con = duckdb.connect("fake.duckdb")

# %%
con.read_csv("./generated_data_01.csv")

# %%
sql = """
CREATE TABLE data_01 AS
(select SKU, description, price from generated_data_01.csv)
"""

con.sql(sql)

# %%
sql = """
CREATE TABLE data_02 AS
(select SKU, description, price from generated_data_02.csv)
"""

con.sql(sql)

# %%
# save data to parquet file
con.close()

# %%
# reopen
con = duckdb.connect("fake.duckdb")

# %%
sql = "CREATE TABLE similarity_matrix (sku_a TEXT, description_a TEXT, sku_b TEXT, description_b TEXT, similar_ratio FLOAT);"
con.execute(sql)

# %%
sql = "select sku, description from data_01 limit 500;"
rs = con.execute(sql).fetchall()

# %%
sql = "select sku, description from data_01 limit 500 offset 500;"
rs2 = con.execute(sql).fetchall()

# %%
rs

# %%
rs2

# %%
from thefuzz import fuzz
sm = []
for row in rs:
    for row2 in rs2:
        sr = fuzz.ratio(row[1], row2[1])
        if sr > 70:
            print(f"{row[1]}, {row2[1]}, {sr}")
            sm.append((row[0], row[1], row2[0], row2[1], sr))
#
sql = "insert into similarity_matrix (sku_a, description_a, sku_b, description_b, similar_ratio) values (?, ?, ?, ?, ?);"
con.executemany(sql, sm)

# %%
con.close()

# %%
con = duckdb.connect("products.duckdb")
con.execute("select * from similarity_matrix order by sku_a, similar_ratio desc, sku_b limit 100 ").fetchall()

# %%
# https://medium.com/@ilakk2023/advanced-sql-features-in-duckdb-window-functions-common-table-expressions-and-more-bbf9c4216986
sql = """
select * from (
SELECT sku_a, description_a, sku_b, description_b, similar_ratio, 
        row_number() OVER (PARTITION BY sku_a ORDER BY similar_ratio desc) as rn
FROM similarity_matrix
) where rn < 3;
"""
con.execute(sql).fetchall()

# %%
# COPY (SELECT * FROM tbl) TO 'output.csv' (HEADER, DELIMITER ',');
sql = """
COPY (
    select * from (
    SELECT sku_a, description_a, sku_b, description_b, similarity, 
            row_number() OVER (PARTITION BY sku_a ORDER BY similarity desc) as rn
    FROM data_all where similarity > 80 
    ) where rn < 3
) TO 'similarity_matrix_output.csv' (HEADER, DELIMITER ',');
"""
con.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       1 # COPY (SELECT * FROM tbl) TO 'output.csv' (HEADER, DELIMITER ',');
#       2 sql = """
#       3 COPY (
#       4     select * from (
#    (...)
#       9 ) TO 'similarity_matrix_output.csv' (HEADER, DELIMITER ',');
#      10 """
# ---> 11 con.execute(sql)
#
# NameError: name 'con' is not defined

# %%
from duckdb.typing import *
from faker import Faker

def generate_random_name():
    fake = Faker()
    return fake.name()

duckdb.create_function("random_name", generate_random_name, [], VARCHAR)
res = duckdb.sql("SELECT random_name()").fetchall()
print(res)

# %%
res = duckdb.sql("SELECT random_name()").fetchall()
print(res)
# Out:
# [('Lauren Kemp',)]

# %%
from thefuzz import fuzz
def fuzzy_similarity(str1: str, str2: str) -> int:
    return fuzz.ratio(str1, str2)

# %%
con.create_function("fuzzy_similarity", fuzzy_similarity)

# %%
res = con.sql("SELECT fuzzy_similarity('a', 'b')").fetchall()
res
# Out:
# [(0,)]

# %%
sql = """
SELECT t2.sku as sku_a, t2.description as description_a, t0.sku as sku_b, t0.description as description_b,
        fuzzy_similarity(t0.description, t2.description) as similarity
FROM data_02 t2, data_01 t0
"""
res = con.execute(sql).fetchall()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.close()

# %%
sql = """
CREATE TABLE data_all as
select t0.sku as sku_a, t0.description as description_a,
       t1.sku as sku_b, t1.description as description_b,
       0 as similarity
from
(select SKU, description, price from generated_data_01.csv) t0,
(select SKU, description, price from generated_data_02.csv) t1,
"""

con.sql(sql)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
sql = """
update data_all set similarity = fuzzy_similarity(description_a, description_b);
"""
con.execute(sql).fetchall()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [(100000000,)]

# %%
sql = """
select * from data_all where similarity > 80 order by sku_a, sku_b, similarity desc;
"""
con.execute(sql).fetchall()
# Out:
# [('001-21-6217',
#   'Reverse-engineered well-modulated matrix',
#   '707-13-6022',
#   'Reverse-engineered well-modulated conglomeration',
#   86),
#  ('001-24-3801',
#   'Cross-group foreground portal',
#   '544-40-0053',
#   'Cross-group foreground intranet',
#   83),
#  ('001-38-6253',
#   'Integrated 5thgeneration moratorium',
#   '437-80-3650',
#   'Inverse 5thgeneration moderator',
#   82),
#  ('001-38-6253',
#   'Integrated 5thgeneration moratorium',
#   '446-64-4004',
#   'Integrated 4thgeneration moratorium',
#   97),
#  ('001-38-6253',
#   'Integrated 5thgeneration moratorium',
#   '560-25-3133',
#   'Ameliorated 4thgeneration moratorium',
#   85),
#  ('001-49-4694',
#   'Function-based scalable pricing structure',
#   '233-35-0529',
#   'Function-based scalable infrastructure',
#   89),
#  ('001-52-2137',
#   'Upgradable incremental time-frame',
#   '199-83-6564',
#   'Versatile incremental time-frame',
#   83),
#  ('001-63-6504',
#   'User-friendly mobile concept',
#   '279-18-3815',
#   'User-friendly logistical concept',
#   83),
#  ('001-65-2310',
#   'Automated heuristic orchestration',
#   '075-12-1565',
#   'Automated reciprocal orchestration',
#   81),
#  ('001-65-2310',
#   'Automated heuristic orchestration',
#   '796-20-3543',
#   'Object-based heuristic orchestration',
#   81),
#  ('001-71-8634',
#   'Realigned uniform firmware',
#   '212-14-3189',
#   'Right-sized uniform firmware',
#   81),
#  ('001-71-8634',
#   'Realigned uniform firmware',
#   '527-65-3216',
#   'Realigned uniform firmware',
#   100),
#  ('001-90-3919',
#   'Polarized dynamic service-desk',
#   '093-80-9699',
#   'Polarized analyzing service-desk',
#   84),
#  ('001-90-3919',
#   'Polarized dynamic service-desk',
#   '461-44-0597',
#   'Team-oriented dynamic service-desk',
#   81),
#  ('002-10-5957',
#   'Integrated heuristic data-warehouse',
#   '802-86-0124',
#   'Future-proofed heuristic data-warehouse',
#   81),
#  ('002-24-1974',
#   'Exclusive multi-state intranet',
#   '177-12-9465',
#   'Exclusive multi-state Graphic Interface',
#   81),
#  ('002-36-4819',
#   'Visionary full-range hierarchy',
#   '673-50-4784',
#   'Visionary full-range contingency',
#   81),
#  ('002-39-8341',
#   'Customer-focused secondary open architecture',
#   '821-32-6234',
#   'Customer-focused multimedia open architecture',
#   85),
#  ('002-39-8341',
#   'Customer-focused secondary open architecture',
#   '847-65-5781',
#   'Customer-focused secondary structure',
#   82),
#  ('002-61-7639',
#   'Virtual maximized implementation',
#   '405-26-4685',
#   'Virtual radical implementation',
#   81),
#  ('002-68-6815',
#   'Extended human-resource process improvement',
#   '385-61-8500',
#   'Fundamental human-resource process improvement',
#   85),
#  ('002-79-6045',
#   'Optional motivating standardization',
#   '116-34-6291',
#   'Optional motivating installation',
#   84),
#  ('002-82-4429',
#   'Adaptive bi-directional infrastructure',
#   '094-30-2238',
#   'Adaptive bi-directional forecast',
#   83),
#  ('002-82-4429',
#   'Adaptive bi-directional infrastructure',
#   '146-68-8824',
#   'Diverse directional infrastructure',
#   83),
#  ('002-82-4429',
#   'Adaptive bi-directional infrastructure',
#   '742-62-8830',
#   'Adaptive bi-directional success',
#   81),
#  ('002-83-1741',
#   'Multi-channeled mobile definition',
#   '841-30-1346',
#   'Multi-channeled value-added definition',
#   82),
#  ('002-89-6702',
#   'Seamless impactful productivity',
#   '613-59-6259',
#   'Reduced impactful productivity',
#   82),
#  ('003-12-4514',
#   'Inverse tertiary conglomeration',
#   '752-07-5093',
#   'Inverse tertiary orchestration',
#   82),
#  ('003-12-4514',
#   'Inverse tertiary conglomeration',
#   '810-24-6432',
#   'Inverse exuding conglomeration',
#   82),
#  ('003-21-1103',
#   'Reverse-engineered system-worthy instruction set',
#   '359-22-4436',
#   'Reverse-engineered secondary instruction set',
#   87),
#  ('003-31-7745',
#   'Cross-group zero administration attitude',
#   '752-69-5402',
#   'Cross-group zero administration database',
#   88),
#  ('003-43-3081',
#   'Multi-channeled disintermediate parallelism',
#   '122-93-8902',
#   'Multi-channeled disintermediate intranet',
#   84),
#  ('003-43-3081',
#   'Multi-channeled disintermediate parallelism',
#   '264-38-2648',
#   'Multi-channeled stable parallelism',
#   83),
#  ('003-44-4747',
#   'Synergistic multi-state complexity',
#   '585-57-8592',
#   'Synergistic multi-state conglomeration',
#   81),
#  ('003-44-4747',
#   'Synergistic multi-state complexity',
#   '607-44-7905',
#   'Synergistic mobile complexity',
#   83),
#  ('003-80-5437',
#   'Intuitive zero administration info-mediaries',
#   '385-72-1256',
#   'Synergistic zero administration info-mediaries',
#   87),
#  ('003-99-3966',
#   'Down-sized transitional superstructure',
#   '661-79-8134',
#   'Devolved transitional superstructure',
#   86),
#  ('004-04-5588',
#   'Upgradable intangible monitoring',
#   '821-01-2358',
#   'Upgradable intermediate monitoring',
#   82),
#  ('004-04-5588',
#   'Upgradable intangible monitoring',
#   '847-54-6634',
#   'Upgradable intangible concept',
#   82),
#  ('004-09-9124',
#   'Quality-focused zero administration Local Area Network',
#   '049-63-5960',
#   'Quality-focused holistic Local Area Network',
#   82),
#  ('004-13-8550',
#   'Open-source leadingedge product',
#   '473-82-9236',
#   'Open-source leadingedge protocol',
#   89),
#  ('004-30-7590',
#   'Compatible context-sensitive workforce',
#   '394-99-5391',
#   'Expanded context-sensitive workforce',
#   84),
#  ('004-30-7590',
#   'Compatible context-sensitive workforce',
#   '562-08-3713',
#   'Balanced context-sensitive workforce',
#   84),
#  ('004-40-1782',
#   'Focused modular projection',
#   '173-72-5440',
#   'Monitored modular projection',
#   81),
#  ('004-54-1393',
#   'Object-based web-enabled system engine',
#   '841-20-7248',
#   'Object-based local system engine',
#   83),
#  ('004-64-2385',
#   'Digitized attitude-oriented function',
#   '030-30-0250',
#   'Optimized attitude-oriented function',
#   89),
#  ('004-64-2385',
#   'Digitized attitude-oriented function',
#   '487-59-4670',
#   'Versatile attitude-oriented function',
#   83),
#  ('004-96-0514',
#   'Optimized empowering neural-net',
#   '126-94-0063',
#   'Automated empowering neural-net',
#   84),
#  ('004-97-4854',
#   'Enterprise-wide bottom-line system engine',
#   '854-18-5796',
#   'Diverse bottom-line system engine',
#   81),
#  ('005-01-6827',
#   'Synchronized context-sensitive parallelism',
#   '058-39-8962',
#   'Diverse context-sensitive parallelism',
#   81),
#  ('005-01-6827',
#   'Synchronized context-sensitive parallelism',
#   '275-03-9733',
#   'Configurable context-sensitive parallelism',
#   81),
#  ('005-08-4831',
#   'Universal interactive adapter',
#   '524-04-1459',
#   'Universal systematic adapter',
#   81),
#  ('005-17-4213',
#   'Synchronized directional concept',
#   '386-55-5331',
#   'Synchronized directional moratorium',
#   81),
#  ('005-30-3969',
#   'Enhanced logistical policy',
#   '461-28-9875',
#   'Enhanced logistical product',
#   87),
#  ('005-44-1895',
#   'Right-sized contextually-based ability',
#   '590-37-8637',
#   'Operative contextually-based ability',
#   81),
#  ('005-49-6975',
#   'Proactive directional installation',
#   '470-03-6809',
#   'Sharable directional installation',
#   84),
#  ('005-49-6975',
#   'Proactive directional installation',
#   '701-73-8266',
#   'Proactive directional implementation',
#   86),
#  ('005-49-6975',
#   'Proactive directional installation',
#   '746-20-5137',
#   'Proactive logistical installation',
#   84),
#  ('005-80-3790',
#   'Multi-layered incremental focus group',
#   '382-68-5880',
#   'Multi-layered high-level focus group',
#   82),
#  ('005-80-3790',
#   'Multi-layered incremental focus group',
#   '403-04-7034',
#   'Public-key incremental focus group',
#   82),
#  ('006-15-9226',
#   'Sharable 24hour pricing structure',
#   '785-94-5879',
#   'Advanced 24hour pricing structure',
#   82),
#  ('006-18-8217',
#   'Front-line national infrastructure',
#   '216-49-9835',
#   'Front-line holistic infrastructure',
#   82),
#  ('006-24-5881',
#   'Re-contextualized logistical project',
#   '664-80-0445',
#   'Centralized logistical project',
#   85),
#  ('006-31-3891',
#   'Synchronized coherent portal',
#   '026-03-3850',
#   'Synchronized coherent access',
#   82),
#  ('006-40-7611',
#   'Re-engineered optimizing support',
#   '573-65-0154',
#   'Re-engineered optimizing access',
#   83),
#  ('006-59-5496',
#   'Synergistic regional algorithm',
#   '644-32-3952',
#   'Synergistic regional ability',
#   86),
#  ('006-61-7783',
#   'Cross-platform user-facing approach',
#   '893-08-7261',
#   'Cross-platform user-facing access',
#   85),
#  ('006-75-2165',
#   'Open-architected modular implementation',
#   '435-54-7042',
#   'Open-architected needs-based implementation',
#   83),
#  ('006-75-2165',
#   'Open-architected modular implementation',
#   '673-78-9035',
#   'Open-architected incremental implementation',
#   83),
#  ('006-75-2165',
#   'Open-architected modular implementation',
#   '802-67-9690',
#   'Open-architected demand-driven implementation',
#   83),
#  ('006-89-2506',
#   'Persevering even-keeled utilization',
#   '729-83-3424',
#   'Pre-emptive even-keeled utilization',
#   83),
#  ('007-27-5872',
#   'Progressive logistical forecast',
#   '844-19-9710',
#   'Progressive logistical hardware',
#   81),
#  ('007-27-5872',
#   'Progressive logistical forecast',
#   '859-71-8855',
#   'Progressive logistical software',
#   84),
#  ('007-47-1726',
#   'Seamless needs-based software',
#   '037-17-4655',
#   'Diverse needs-based software',
#   81),
#  ('007-47-1726',
#   'Seamless needs-based software',
#   '482-38-7645',
#   'Seamless needs-based synergy',
#   81),
#  ('007-50-8590',
#   'Streamlined encompassing hardware',
#   '525-08-1557',
#   'Centralized encompassing hardware',
#   88),
#  ('007-59-1504',
#   'Proactive zero administration instruction set',
#   '246-28-5422',
#   'Proactive national instruction set',
#   81),
#  ('007-59-1504',
#   'Proactive zero administration instruction set',
#   '740-65-7355',
#   'Operative zero administration structure',
#   81),
#  ('007-73-6950',
#   'Cross-group interactive process improvement',
#   '494-83-7342',
#   'Cross-group coherent process improvement',
#   84),
#  ('007-76-1270',
#   'Configurable bottom-line Internet solution',
#   '190-83-0301',
#   'Sharable bottom-line Internet solution',
#   88),
#  ('007-76-1270',
#   'Configurable bottom-line Internet solution',
#   '337-76-1767',
#   'Configurable bottom-line Internet solution',
#   100),
#  ('007-76-1270',
#   'Configurable bottom-line Internet solution',
#   '520-41-9793',
#   'Enhanced bottom-line Internet solution',
#   82),
#  ('007-79-3369',
#   'Upgradable tertiary approach',
#   '085-85-9907',
#   'Upgradable 5thgeneration approach',
#   82),
#  ('007-80-5050',
#   'Face-to-face web-enabled monitoring',
#   '755-30-5750',
#   'Face-to-face incremental monitoring',
#   83),
#  ('008-06-6775',
#   'Team-oriented global groupware',
#   '560-90-2612',
#   'Team-oriented local groupware',
#   95),
#  ('008-06-6775',
#   'Team-oriented global groupware',
#   '881-58-4991',
#   'Team-oriented global groupware',
#   100),
#  ('008-09-0621',
#   'Cross-group background website',
#   '387-38-0641',
#   'Cross-group background ability',
#   87),
#  ('008-31-3113',
#   'Advanced fault-tolerant middleware',
#   '768-40-6120',
#   'Extended fault-tolerant middleware',
#   85),
#  ('008-33-0047',
#   'Future-proofed object-oriented projection',
#   '537-20-3381',
#   'Automated object-oriented projection',
#   83),
#  ('008-35-8632',
#   'Realigned regional access',
#   '117-13-9728',
#   'Reduced regional access',
#   83),
#  ('008-39-7630',
#   'Public-key solution-oriented Local Area Network',
#   '615-13-3584',
#   'Proactive solution-oriented Local Area Network',
#   86),
#  ('008-40-4819',
#   'Expanded cohesive Local Area Network',
#   '290-10-0156',
#   'Expanded dedicated Local Area Network',
#   85),
#  ('008-83-3339',
#   'User-friendly stable neural-net',
#   '462-87-7236',
#   'User-centric stable neural-net',
#   82),
#  ('009-36-4124',
#   'Cross-platform mission-critical concept',
#   '685-19-9945',
#   'Cross-platform mission-critical benchmark',
#   85),
#  ('009-63-6784',
#   'Enterprise-wide multi-state info-mediaries',
#   '483-26-9449',
#   'Enterprise-wide client-driven info-mediaries',
#   81),
#  ('009-97-3873',
#   'Multi-channeled asynchronous solution',
#   '773-90-5354',
#   'Multi-channeled asynchronous secured line',
#   85),
#  ('010-19-5732',
#   'Right-sized intermediate focus group',
#   '614-04-3833',
#   'Right-sized intermediate solution',
#   81),
#  ('010-32-3662',
#   'Configurable zero administration moderator',
#   '280-20-6333',
#   'Configurable zero administration parallelism',
#   81),
#  ('010-32-3662',
#   'Configurable zero administration moderator',
#   '890-44-9393',
#   'Configurable zero administration definition',
#   87),
#  ('010-48-3298',
#   'De-engineered local methodology',
#   '563-64-5683',
#   'Re-engineered tangible methodology',
#   83),
#  ('010-48-3298',
#   'De-engineered local methodology',
#   '847-30-9566',
#   'Re-engineered uniform methodology',
#   81),
#  ('010-78-6162',
#   'Implemented human-resource access',
#   '482-38-5710',
#   'Realigned human-resource access',
#   81),
#  ('010-79-1858',
#   'Assimilated client-driven projection',
#   '473-42-2110',
#   'Assimilated client-driven policy',
#   85),
#  ('010-79-1858',
#   'Assimilated client-driven projection',
#   '657-81-6412',
#   'Assimilated client-server project',
#   87),
#  ('010-79-1858',
#   'Assimilated client-driven projection',
#   '698-53-4838',
#   'Up-sized client-driven projection',
#   84),
#  ('010-90-3943',
#   'Profit-focused 6thgeneration neural-net',
#   '039-51-2285',
#   'Profit-focused 4thgeneration alliance',
#   84),
#  ('010-90-3943',
#   'Profit-focused 6thgeneration neural-net',
#   '303-87-6821',
#   'Profit-focused 4thgeneration leverage',
#   84),
#  ('010-92-8650',
#   'Multi-channeled even-keeled open system',
#   '347-20-0510',
#   'Multi-channeled high-level open system',
#   83),
#  ('010-92-8650',
#   'Multi-channeled even-keeled open system',
#   '688-83-4083',
#   'Multi-channeled intangible open system',
#   81),
#  ('011-20-9648',
#   'Cross-platform explicit capability',
#   '715-90-2239',
#   'Cross-group explicit capability',
#   83),
#  ('011-51-1873',
#   'Open-architected solution-oriented workforce',
#   '348-78-3584',
#   'Open-architected solution-oriented service-desk',
#   84),
#  ('011-56-7774',
#   'Versatile object-oriented contingency',
#   '062-70-2777',
#   'Versatile object-oriented structure',
#   81),
#  ('011-56-7774',
#   'Versatile object-oriented contingency',
#   '254-09-4176',
#   'Versatile solution-oriented contingency',
#   87),
#  ('011-62-5901',
#   'Synergized needs-based challenge',
#   '292-92-2838',
#   'Synergized needs-based extranet',
#   83),
#  ('011-73-2963',
#   'Innovative well-modulated database',
#   '774-46-4055',
#   'Innovative well-modulated leverage',
#   82),
#  ('012-04-1074',
#   'Object-based clear-thinking success',
#   '265-23-9195',
#   'Object-based clear-thinking adapter',
#   83),
#  ('012-29-3157',
#   'Re-engineered next generation secured line',
#   '754-70-0082',
#   'Re-engineered next generation structure',
#   86),
#  ('012-82-4464',
#   'Streamlined real-time structure',
#   '505-79-2058',
#   'Centralized real-time infrastructure',
#   81),
#  ('012-82-4464',
#   'Streamlined real-time structure',
#   '541-22-2478',
#   'Seamless real-time structure',
#   88),
#  ('012-83-9960',
#   'Switchable solution-oriented support',
#   '052-33-7560',
#   'Switchable solution-oriented projection',
#   85),
#  ('013-01-2024',
#   'Up-sized interactive challenge',
#   '215-45-5639',
#   'Expanded interactive challenge',
#   83),
#  ('013-46-6517',
#   'Team-oriented incremental process improvement',
#   '622-24-1312',
#   'Team-oriented global process improvement',
#   85),
#  ('013-46-6517',
#   'Team-oriented incremental process improvement',
#   '688-68-0939',
#   'Team-oriented systematic process improvement',
#   83),
#  ('013-55-7999',
#   'Mandatory client-driven architecture',
#   '899-54-8657',
#   'Mandatory national architecture',
#   81),
#  ('013-73-5459',
#   'Monitored static conglomeration',
#   '459-17-6900',
#   'Monitored motivating conglomeration',
#   88),
#  ('013-73-5459',
#   'Monitored static conglomeration',
#   '839-67-5742',
#   'Organized static conglomeration',
#   84),
#  ('013-87-1702',
#   'Function-based cohesive interface',
#   '168-23-3027',
#   'Down-sized cohesive interface',
#   81),
#  ('013-87-1702',
#   'Function-based cohesive interface',
#   '243-26-5744',
#   'Function-based cohesive firmware',
#   86),
#  ('013-87-1702',
#   'Function-based cohesive interface',
#   '877-39-3288',
#   'Function-based cohesive array',
#   84),
#  ('013-89-8241',
#   'Devolved intangible solution',
#   '821-03-2371',
#   'Devolved intangible contingency',
#   81),
#  ('013-95-8594',
#   'Implemented dedicated challenge',
#   '008-92-2193',
#   'Implemented dedicated benchmark',
#   81),
#  ('014-42-7259',
#   'Quality-focused local Internet solution',
#   '372-84-9937',
#   'Quality-focused executive Internet solution',
#   85),
#  ('014-48-8541',
#   'Re-engineered motivating encryption',
#   '163-83-6631',
#   'De-engineered motivating encryption',
#   97),
#  ('014-48-8541',
#   'Re-engineered motivating encryption',
#   '176-01-4287',
#   'De-engineered multi-state encryption',
#   82),
#  ('014-48-8541',
#   'Re-engineered motivating encryption',
#   '343-93-9721',
#   'Re-engineered dynamic encryption',
#   81),
#  ('014-70-7359',
#   'Assimilated directional productivity',
#   '383-88-3008',
#   'Balanced bi-directional productivity',
#   81),
#  ('014-70-7359',
#   'Assimilated directional productivity',
#   '582-46-8859',
#   'Up-sized directional productivity',
#   84),
#  ('014-71-2719',
#   'Intuitive system-worthy complexity',
#   '131-25-0497',
#   'Optimized system-worthy complexity',
#   85),
#  ('014-71-2719',
#   'Intuitive system-worthy complexity',
#   '361-43-8736',
#   'Cloned system-worthy complexity',
#   83),
#  ('015-03-9520',
#   'Optional 3rdgeneration knowledgebase',
#   '802-96-0976',
#   'Optional 3rdgeneration database',
#   84),
#  ('015-14-9163',
#   'Automated transitional initiative',
#   '164-39-3355',
#   'Focused transitional initiative',
#   84),
#  ('015-14-9163',
#   'Automated transitional initiative',
#   '280-18-4540',
#   'Automated transitional frame',
#   82),
#  ('015-14-9163',
#   'Automated transitional initiative',
#   '859-11-5863',
#   'Front-line transitional initiative',
#   81),
#  ('015-19-0221',
#   'Optimized high-level Local Area Network',
#   '588-80-1606',
#   'Optimized high-level Local Area Network',
#   100),
#  ('015-43-4293',
#   'Cross-group tangible architecture',
#   '065-97-7522',
#   'Cross-group tangible circuit',
#   82),
#  ('015-85-9769',
#   'Universal coherent success',
#   '502-91-0419',
#   'Virtual coherent success',
#   84),
#  ('016-06-4868',
#   'Future-proofed even-keeled application',
#   '020-07-5638',
#   'Integrated even-keeled application',
#   81),
#  ('016-06-4868',
#   'Future-proofed even-keeled application',
#   '228-74-7545',
#   'Future-proofed even-keeled archive',
#   83),
#  ('016-06-5410',
#   'Open-architected multimedia attitude',
#   '094-67-0778',
#   'Open-architected optimizing attitude',
#   83),
#  ('016-06-5410',
#   'Open-architected multimedia attitude',
#   '418-29-1367',
#   'Open-architected explicit attitude',
#   83),
#  ('016-09-8976',
#   'Future-proofed coherent Local Area Network',
#   '585-39-3852',
#   'Future-proofed zero-defect Local Area Network',
#   87),
#  ('016-17-2652',
#   'Grass-roots directional methodology',
#   '055-56-2161',
#   'Grass-roots dynamic methodology',
#   82),
#  ('016-21-3987',
#   'Monitored static monitoring',
#   '197-99-4409',
#   'Monitored systematic monitoring',
#   93),
#  ('016-29-4280',
#   'Open-architected maximized application',
#   '317-92-5733',
#   'Open-architected maximized algorithm',
#   84),
#  ('016-36-3073',
#   'Monitored multimedia conglomeration',
#   '459-17-6900',
#   'Monitored motivating conglomeration',
#   83),
#  ('016-37-7982',
#   'Inverse client-driven array',
#   '292-16-5475',
#   'Inverse client-driven framework',
#   83),
#  ('016-44-9687',
#   'Inverse client-server pricing structure',
#   '153-04-6661',
#   'Mandatory client-server pricing structure',
#   85),
#  ('016-44-9687',
#   'Inverse client-server pricing structure',
#   '835-49-0411',
#   'Inverse client-driven pricing structure',
#   92),
#  ('016-47-6166',
#   'Exclusive next generation standardization',
#   '107-73-8625',
#   'Polarized next generation standardization',
#   85),
#  ('016-65-4085',
#   'Inverse human-resource implementation',
#   '021-56-4640',
#   'Devolved human-resource implementation',
#   85),
#  ('016-65-4085',
#   'Inverse human-resource implementation',
#   '293-15-5274',
#   'Fundamental human-resource implementation',
#   82),
#  ('016-65-4085',
#   'Inverse human-resource implementation',
#   '379-70-5749',
#   'Assimilated human-resource implementation',
#   82),
#  ('016-85-7116',
#   'Customer-focused local conglomeration',
#   '418-44-9198',
#   'Customer-focused hybrid conglomeration',
#   85),
#  ('016-86-9825',
#   'Customer-focused object-oriented core',
#   '166-07-3679',
#   'Customer-focused object-oriented middleware',
#   88),
#  ('016-86-9825',
#   'Customer-focused object-oriented core',
#   '314-83-7769',
#   'Customer-focused object-oriented customer loyalty',
#   84),
#  ('016-86-9825',
#   'Customer-focused object-oriented core',
#   '754-01-4399',
#   'Customer-focused object-oriented initiative',
#   85),
#  ('016-86-9825',
#   'Customer-focused object-oriented core',
#   '830-12-7428',
#   'Customer-focused object-oriented superstructure',
#   86),
#  ('016-86-9825',
#   'Customer-focused object-oriented core',
#   '847-02-3892',
#   'Customer-focused object-oriented superstructure',
#   86),
#  ('017-52-2966',
#   'Business-focused homogeneous secured line',
#   '785-10-1101',
#   'Business-focused uniform secured line',
#   82),
#  ('017-65-0301',
#   'Centralized web-enabled attitude',
#   '219-75-4077',
#   'Decentralized web-enabled structure',
#   81),
#  ('017-73-7775',
#   'Networked incremental emulation',
#   '779-96-9861',
#   'Networked methodical emulation',
#   82),
#  ('018-05-6875',
#   'Universal asymmetric customer loyalty',
#   '470-23-0638',
#   'Universal discrete customer loyalty',
#   83),
#  ('018-10-3673',
#   'Exclusive empowering system engine',
#   '389-33-8069',
#   'Reactive empowering system engine',
#   87),
#  ('018-20-1000',
#   'Business-focused context-sensitive matrix',
#   '130-11-5982',
#   'Business-focused context-sensitive framework',
#   87),
#  ('018-28-0727',
#   'Devolved object-oriented orchestration',
#   '881-05-5024',
#   'Business-focused object-oriented orchestration',
#   81),
#  ('018-88-4374',
#   'Expanded bi-directional access',
#   '711-14-2671',
#   'Expanded bi-directional attitude',
#   84),
#  ('019-64-9978',
#   'Organized didactic collaboration',
#   '817-12-4761',
#   'Organized actuating collaboration',
#   86),
#  ('019-64-9978',
#   'Organized didactic collaboration',
#   '892-16-0838',
#   'Organized didactic solution',
#   85),
#  ('019-67-8083',
#   'Multi-layered composite customer loyalty',
#   '870-68-3806',
#   'Multi-layered global customer loyalty',
#   83),
#  ('019-69-6648',
#   'Reduced real-time customer loyalty',
#   '196-38-4399',
#   'Polarized real-time customer loyalty',
#   83),
#  ('019-69-6648',
#   'Reduced real-time customer loyalty',
#   '344-37-8678',
#   'Public-key real-time customer loyalty',
#   85),
#  ('019-75-5913',
#   'Networked dynamic open architecture',
#   '331-48-3986',
#   'Networked systematic open architecture',
#   88),
#  ('019-75-5913',
#   'Networked dynamic open architecture',
#   '332-55-0290',
#   'Networked national architecture',
#   85),
#  ('019-75-5913',
#   'Networked dynamic open architecture',
#   '337-26-2889',
#   'Persistent dynamic open architecture',
#   82),
#  ('020-04-4471',
#   'Persevering heuristic instruction set',
#   '139-55-7987',
#   'Persevering heuristic projection',
#   81),
#  ('020-41-3768',
#   'Fully-configurable bi-directional success',
#   '613-05-8859',
#   'Fully-configurable directional attitude',
#   82),
#  ('020-47-3452',
#   'Fundamental attitude-oriented utilization',
#   '630-97-2038',
#   'Fundamental attitude-oriented matrices',
#   84),
#  ('020-62-6480',
#   'Multi-tiered national matrices',
#   '739-23-9726',
#   'Multi-tiered optimizing matrices',
#   81),
#  ('020-86-6894',
#   'Future-proofed tangible protocol',
#   '414-20-7312',
#   'Future-proofed tangible moratorium',
#   82),
#  ('020-86-6894',
#   'Future-proofed tangible protocol',
#   '586-67-0178',
#   'Future-proofed tangible access',
#   81),
#  ('020-96-4721',
#   'Phased attitude-oriented time-frame',
#   '809-92-4281',
#   'Down-sized attitude-oriented time-frame',
#   86),
#  ('020-96-4721',
#   'Phased attitude-oriented time-frame',
#   '860-62-5169',
#   'Phased attitude-oriented frame',
#   92),
#  ('020-97-4196',
#   'Business-focused empowering help-desk',
#   '016-08-7244',
#   'Business-focused empowering archive',
#   83),
#  ('020-97-4196',
#   'Business-focused empowering help-desk',
#   '246-24-3635',
#   'Business-focused zero tolerance help-desk',
#   82),
#  ('021-06-8705',
#   'Customer-focused dynamic emulation',
#   '209-36-2365',
#   'Customer-focused dynamic neural-net',
#   84),
#  ('021-19-7509',
#   'Advanced leadingedge emulation',
#   '696-73-6574',
#   'Advanced leadingedge matrices',
#   85),
#  ('021-19-7509',
#   'Advanced leadingedge emulation',
#   '876-84-1119',
#   'Advanced leadingedge moderator',
#   83),
#  ('022-11-6659',
#   'Expanded upward-trending knowledge user',
#   '310-90-5786',
#   'Expanded upward-trending leverage',
#   81),
#  ('022-28-5795',
#   'Centralized non-volatile knowledge user',
#   '551-43-9286',
#   'Networked non-volatile knowledge user',
#   87),
#  ('022-28-5795',
#   'Centralized non-volatile knowledge user',
#   '796-72-0963',
#   'Exclusive non-volatile knowledge user',
#   82),
#  ('022-28-5795',
#   'Centralized non-volatile knowledge user',
#   '850-04-1400',
#   'Team-oriented non-volatile knowledge user',
#   82),
#  ('022-28-6721',
#   'Monitored non-volatile success',
#   '644-89-6903',
#   'Synchronized non-volatile success',
#   83),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '407-78-2891',
#   'Future-proofed local structure',
#   82),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '424-55-1449',
#   'Future-proofed web-enabled core',
#   81),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '495-45-1114',
#   'Future-proofed reciprocal core',
#   82),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '678-07-8558',
#   'Future-proofed global help-desk',
#   81),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '851-99-1293',
#   'Future-proofed local groupware',
#   82),
#  ('022-41-2501',
#   'Future-proofed global core',
#   '877-56-3865',
#   'Future-proofed local project',
#   81),
#  ('022-51-0135',
#   'Front-line real-time concept',
#   '596-29-8641',
#   'Front-line real-time project',
#   86),
#  ('022-51-0135',
#   'Front-line real-time concept',
#   '711-37-9531',
#   'Front-line regional concept',
#   84),
#  ('022-64-2636',
#   'Public-key encompassing info-mediaries',
#   '173-70-7119',
#   'Multi-layered encompassing info-mediaries',
#   84),
#  ('022-70-4581',
#   'Right-sized systematic info-mediaries',
#   '798-39-0174',
#   'Ameliorated systematic info-mediaries',
#   81),
#  ('022-77-1870',
#   'Seamless actuating definition',
#   '425-94-9764',
#   'Seamless actuating installation',
#   83),
#  ('022-90-5461',
#   'Extended executive help-desk',
#   '582-95-3015',
#   'Extended cohesive help-desk',
#   84),
#  ('023-14-1674',
#   'Assimilated explicit process improvement',
#   '270-35-1828',
#   'Devolved explicit process improvement',
#   83),
#  ('023-19-9013',
#   'Monitored next generation customer loyalty',
#   '774-41-7710',
#   'Multi-tiered 6thgeneration customer loyalty',
#   82),
#  ('023-32-6368',
#   'De-engineered explicit alliance',
#   '572-22-3471',
#   'De-engineered impactful alliance',
#   83),
#  ('023-40-9919',
#   'Centralized contextually-based groupware',
#   '174-54-1418',
#   'Decentralized contextually-based focus group',
#   83),
#  ('023-40-9919',
#   'Centralized contextually-based groupware',
#   '378-07-5910',
#   'Cloned contextually-based groupware',
#   88),
#  ('023-40-9919',
#   'Centralized contextually-based groupware',
#   '586-14-0796',
#   'Extended contextually-based groupware',
#   86),
#  ('023-40-9919',
#   'Centralized contextually-based groupware',
#   '774-72-0656',
#   'Centralized contextually-based matrix',
#   86),
#  ('023-44-3461',
#   'Versatile next generation conglomeration',
#   '174-08-7793',
#   'Reactive 3rdgeneration conglomeration',
#   81),
#  ('023-44-3461',
#   'Versatile next generation conglomeration',
#   '795-83-8268',
#   'Managed next generation conglomeration',
#   85),
#  ('024-15-7237',
#   'Visionary value-added utilization',
#   '710-95-8208',
#   'Cloned value-added utilization',
#   83),
#  ('024-50-5429',
#   'Balanced demand-driven attitude',
#   '143-27-4517',
#   'Balanced demand-driven ability',
#   85),
#  ('024-50-5429',
#   'Balanced demand-driven attitude',
#   '824-11-9502',
#   'Compatible demand-driven attitude',
#   81),
#  ('024-75-7863',
#   'Organic mobile time-frame',
#   '083-91-7500',
#   'Organic multimedia time-frame',
#   81),
#  ('024-82-9582',
#   'Progressive contextually-based emulation',
#   '623-52-6857',
#   'Progressive contextually-based alliance',
#   86),
#  ('024-88-2520',
#   'Object-based content-based model',
#   '127-16-5843',
#   'Object-based content-based neural-net',
#   84),
#  ('025-16-4131',
#   'Compatible 24hour model',
#   '843-39-4999',
#   'Compatible 24hour database',
#   82),
#  ('025-38-7048',
#   'Open-architected bandwidth-monitored function',
#   '667-61-4652',
#   'Open-architected bandwidth-monitored matrix',
#   89),
#  ('025-44-8447',
#   'De-engineered object-oriented database',
#   '360-55-0716',
#   'Realigned object-oriented database',
#   83),
#  ('025-44-8447',
#   'De-engineered object-oriented database',
#   '460-54-5531',
#   'De-engineered object-oriented attitude',
#   87),
#  ('025-44-8447',
#   'De-engineered object-oriented database',
#   '586-44-0788',
#   'Devolved object-oriented database',
#   82),
#  ('025-58-8428',
#   'Switchable foreground secured line',
#   '047-29-8485',
#   'Total foreground secured line',
#   86),
#  ('025-58-8428',
#   'Switchable foreground secured line',
#   '616-69-1805',
#   'Digitized foreground secured line',
#   81),
#  ('025-58-8428',
#   'Switchable foreground secured line',
#   '844-30-8298',
#   'Switchable zero-defect secured line',
#   81),
#  ('025-63-1874',
#   'Optimized high-level instruction set',
#   '612-69-8977',
#   'Visionary high-level instruction set',
#   81),
#  ('025-63-1874',
#   'Optimized high-level instruction set',
#   '677-14-1252',
#   'Devolved high-level instruction set',
#   82),
#  ('025-64-3394',
#   'De-engineered cohesive benchmark',
#   '509-09-3486',
#   'De-engineered cohesive website',
#   81),
#  ('025-72-6856',
#   'Open-source actuating focus group',
#   '697-86-6218',
#   'Open-source encompassing focus group',
#   84),
#  ('025-90-2900',
#   'Down-sized solution-oriented framework',
#   '236-09-4609',
#   'Down-sized solution-oriented framework',
#   100),
#  ('025-90-2900',
#   'Down-sized solution-oriented framework',
#   '456-78-1831',
#   'Total solution-oriented framework',
#   82),
#  ('025-90-2900',
#   'Down-sized solution-oriented framework',
#   '661-96-6063',
#   'Intuitive solution-oriented framework',
#   83),
#  ('026-03-8637',
#   'Digitized empowering secured line',
#   '548-89-3252',
#   'Digitized eco-centric secured line',
#   84),
#  ('026-03-8637',
#   'Digitized empowering secured line',
#   '616-69-1805',
#   'Digitized foreground secured line',
#   82),
#  ('026-03-8637',
#   'Digitized empowering secured line',
#   '689-99-4335',
#   'Digitized empowering encoding',
#   84),
#  ('026-17-3801',
#   'Re-engineered analyzing artificial intelligence',
#   '483-54-5115',
#   'Reverse-engineered regional artificial intelligence',
#   84),
#  ('026-17-3801',
#   'Re-engineered analyzing artificial intelligence',
#   '867-70-1579',
#   'De-engineered user-facing artificial intelligence',
#   85),
#  ('026-45-5449',
#   'Optional asynchronous policy',
#   '001-80-3094',
#   'Optional asynchronous array',
#   84),
#  ('026-49-8488',
#   'Cross-group coherent attitude',
#   '061-71-7930',
#   'Cross-group coherent access',
#   82),
#  ('026-58-2158',
#   'Open-architected holistic implementation',
#   '673-78-9035',
#   'Open-architected incremental implementation',
#   82),
#  ('026-80-8594',
#   'Synchronized methodical knowledge user',
#   '636-22-9349',
#   'Synchronized coherent knowledge user',
#   81),
#  ('026-88-0409',
#   'Devolved client-driven standardization',
#   '542-46-3916',
#   'Multi-layered client-driven standardization',
#   81),
#  ('026-88-0409',
#   'Devolved client-driven standardization',
#   '687-26-8841',
#   'Extended client-driven standardization',
#   87),
#  ('026-88-0409',
#   'Devolved client-driven standardization',
#   '689-28-5039',
#   'Pre-emptive client-driven standardization',
#   84),
#  ('026-88-0409',
#   'Devolved client-driven standardization',
#   '758-52-4354',
#   'Secured client-driven standardization',
#   88),
#  ('027-42-2309',
#   'Vision-oriented 3rdgeneration implementation',
#   '055-60-8698',
#   'Vision-oriented radical implementation',
#   83),
#  ('027-42-2309',
#   'Vision-oriented 3rdgeneration implementation',
#   '380-86-8091',
#   'Assimilated 3rdgeneration implementation',
#   83),
#  ('027-43-6661',
#   'De-engineered web-enabled project',
#   '410-26-4103',
#   'De-engineered web-enabled algorithm',
#   82),
#  ('027-43-6661',
#   'De-engineered web-enabled project',
#   '565-66-1744',
#   'De-engineered needs-based project',
#   82),
#  ('027-43-6661',
#   'De-engineered web-enabled project',
#   '566-06-2611',
#   'Re-engineered web-enabled project',
#   97),
#  ('027-58-0136',
#   'Multi-channeled modular standardization',
#   '299-24-8268',
#   'Multi-channeled empowering standardization',
#   86),
#  ('028-13-9989',
#   'Up-sized zero administration projection',
#   '033-65-7747',
#   'Expanded zero administration projection',
#   87),
#  ('028-13-9989',
#   'Up-sized zero administration projection',
#   '107-09-7816',
#   'Persistent zero administration projection',
#   85),
#  ('028-20-1982',
#   'Distributed client-driven pricing structure',
#   '835-49-0411',
#   'Inverse client-driven pricing structure',
#   83),
#  ('028-33-0216',
#   'Focused heuristic interface',
#   '495-03-1297',
#   'Focused heuristic synergy',
#   81),
#  ('028-33-0216',
#   'Focused heuristic interface',
#   '520-86-7340',
#   'Focused heuristic matrices',
#   83),
#  ('028-34-6281',
#   'Expanded multimedia migration',
#   '320-42-3146',
#   'Expanded multimedia installation',
#   85),
#  ('028-37-0178',
#   'Polarized user-facing emulation',
#   '213-09-4508',
#   'Down-sized user-facing emulation',
#   86),
#  ('028-50-2890',
#   'Reverse-engineered bandwidth-monitored hub',
#   '388-96-1687',
#   'Reverse-engineered bandwidth-monitored focus group',
#   87),
#  ('028-60-0405',
#   'Quality-focused real-time architecture',
#   '375-37-0322',
#   'Quality-focused high-level architecture',
#   81),
#  ('028-60-0405',
#   'Quality-focused real-time architecture',
#   '396-47-6596',
#   'Quality-focused regional architecture',
#   88),
#  ('028-60-0405',
#   'Quality-focused real-time architecture',
#   '522-81-5044',
#   'Quality-focused interactive architecture',
#   87),
#  ('028-60-0405',
#   'Quality-focused real-time architecture',
#   '745-94-9862',
#   'Profit-focused real-time open architecture',
#   82),
#  ('028-69-2067',
#   'Sharable encompassing infrastructure',
#   '506-56-4168',
#   'Monitored encompassing infrastructure',
#   82),
#  ('028-94-1019',
#   'Optimized 3rdgeneration instruction set',
#   '881-73-0682',
#   'Optimized 3rdgeneration definition',
#   82),
#  ('028-95-9331',
#   'Cross-group methodical service-desk',
#   '451-23-6221',
#   'Cross-group discrete service-desk',
#   82),
#  ('029-01-2581',
#   'Profound methodical info-mediaries',
#   '261-65-1914',
#   'Profound reciprocal info-mediaries',
#   85),
#  ('029-07-4137',
#   'Advanced needs-based matrix',
#   '818-52-6907',
#   'Advanced needs-based initiative',
#   83),
#  ('029-12-4509',
#   'Persistent system-worthy protocol',
#   '775-94-6662',
#   'Open-architected system-worthy protocol',
#   81),
#  ('029-13-0485',
#   'Distributed 4thgeneration system engine',
#   '156-78-1771',
#   'Decentralized 6thgeneration system engine',
#   82),
#  ('029-13-0485',
#   'Distributed 4thgeneration system engine',
#   '508-18-1097',
#   'Digitized next generation system engine',
#   82),
#  ('029-13-0485',
#   'Distributed 4thgeneration system engine',
#   '725-29-0617',
#   'Upgradable 4thgeneration system engine',
#   81),
#  ('029-13-0485',
#   'Distributed 4thgeneration system engine',
#   '830-99-3021',
#   'Streamlined 5thgeneration system engine',
#   82),
#  ('029-26-0804',
#   'Devolved system-worthy help-desk',
#   '716-76-6903',
#   'Streamlined system-worthy help-desk',
#   84),
#  ('029-29-5797',
#   'Optional next generation collaboration',
#   '375-90-4326',
#   'Innovative next generation collaboration',
#   82),
#  ('029-29-5797',
#   'Optional next generation collaboration',
#   '776-58-1002',
#   'Compatible next generation collaboration',
#   87),
#  ('029-44-6073',
#   'Cloned asymmetric framework',
#   '363-60-1400',
#   'Centralized asymmetric framework',
#   85),
#  ('029-68-9145',
#   'Intuitive bandwidth-monitored knowledgebase',
#   '367-64-6265',
#   'Ergonomic bandwidth-monitored knowledgebase',
#   84),
#  ('029-68-9145',
#   'Intuitive bandwidth-monitored knowledgebase',
#   '676-25-5582',
#   'Configurable bandwidth-monitored knowledgebase',
#   83),
#  ('029-76-0458',
#   'Horizontal high-level challenge',
#   '754-40-8424',
#   'Horizontal high-level parallelism',
#   81),
#  ('029-90-4836',
#   'Progressive directional software',
#   '279-03-2496',
#   'Progressive directional moderator',
#   83),
#  ('029-90-4836',
#   'Progressive directional software',
#   '859-71-8855',
#   'Progressive logistical software',
#   83),
#  ('030-08-5614',
#   'Multi-lateral coherent frame',
#   '390-67-2267',
#   'Multi-lateral coherent paradigm',
#   88),
#  ('030-08-5614',
#   'Multi-lateral coherent frame',
#   '852-86-3315',
#   'Multi-lateral coherent algorithm',
#   83),
#  ('030-11-4468',
#   'Intuitive value-added moderator',
#   '553-78-8094',
#   'Intuitive value-added framework',
#   84),
#  ('030-29-1034',
#   'Vision-oriented multi-state neural-net',
#   '609-50-8826',
#   'Vision-oriented exuding neural-net',
#   81),
#  ('030-49-9464',
#   'Down-sized interactive open system',
#   '420-15-8965',
#   'Down-sized interactive project',
#   81),
#  ('030-62-0373',
#   'Enterprise-wide client-driven website',
#   '483-26-9449',
#   'Enterprise-wide client-driven info-mediaries',
#   81),
#  ('030-62-0373',
#   'Enterprise-wide client-driven website',
#   '580-64-1347',
#   'Enterprise-wide client-server website',
#   92),
#  ('030-64-7085',
#   'Balanced human-resource middleware',
#   '328-64-0462',
#   'Universal human-resource middleware',
#   81),
#  ('030-64-7085',
#   'Balanced human-resource middleware',
#   '355-92-6180',
#   'Balanced human-resource framework',
#   84),
#  ('030-64-7085',
#   'Balanced human-resource middleware',
#   '450-66-1359',
#   'Devolved human-resource middleware',
#   85),
#  ('030-90-6590',
#   'Vision-oriented foreground circuit',
#   '330-60-1416',
#   'Vision-oriented global circuit',
#   81),
#  ('030-90-6590',
#   'Vision-oriented foreground circuit',
#   '612-62-1595',
#   'Vision-oriented foreground middleware',
#   82),
#  ('030-90-6590',
#   'Vision-oriented foreground circuit',
#   '806-56-1920',
#   'Vision-oriented foreground success',
#   85),
#  ('030-90-7891',
#   'Diverse national architecture',
#   '332-55-0290',
#   'Networked national architecture',
#   83),
#  ('031-01-9129',
#   'Configurable neutral focus group',
#   '814-29-5176',
#   'Configurable uniform focus group',
#   84),
#  ('031-04-4629',
#   'Vision-oriented interactive hierarchy',
#   '399-87-2749',
#   'Vision-oriented interactive superstructure',
#   81),
#  ('031-04-4629',
#   'Vision-oriented interactive hierarchy',
#   '404-45-0904',
#   'Vision-oriented interactive methodology',
#   82),
#  ('031-04-4629',
#   'Vision-oriented interactive hierarchy',
#   '894-96-8342',
#   'Vision-oriented interactive firmware',
#   88),
#  ('031-04-5843',
#   'Versatile fresh-thinking orchestration',
#   '407-02-9993',
#   'Organic fresh-thinking orchestration',
#   86),
#  ('031-04-5843',
#   'Versatile fresh-thinking orchestration',
#   '532-41-0698',
#   'Programmable fresh-thinking orchestration',
#   84),
#  ('031-04-5843',
#   'Versatile fresh-thinking orchestration',
#   '539-94-9318',
#   'Face-to-face fresh-thinking orchestration',
#   81),
#  ('031-06-9041',
#   'Optimized human-resource core',
#   '352-71-4114',
#   'Optimized human-resource task-force',
#   88),
#  ('031-10-1069',
#   'Persistent bi-directional projection',
#   '234-53-8051',
#   'Persistent bi-directional emulation',
#   87),
#  ('031-14-4850',
#   'Integrated non-volatile firmware',
#   '559-72-1668',
#   'Adaptive non-volatile firmware',
#   81),
#  ('031-38-2125',
#   'Monitored holistic database',
#   '029-70-9994',
#   'Monitored hybrid database',
#   81),
#  ('031-46-0257',
#   'Expanded upward-trending hierarchy',
#   '096-70-7386',
#   'Expanded upward-trending software',
#   81),
#  ('031-46-0257',
#   'Expanded upward-trending hierarchy',
#   '310-90-5786',
#   'Expanded upward-trending leverage',
#   84),
#  ('031-46-0257',
#   'Expanded upward-trending hierarchy',
#   '442-77-0607',
#   'Synchronized upward-trending hierarchy',
#   81),
#  ('031-46-0257',
#   'Expanded upward-trending hierarchy',
#   '555-28-3067',
#   'Expanded upward-trending algorithm',
#   82),
#  ('031-49-1357',
#   'Inverse optimizing neural-net',
#   '379-86-2751',
#   'Monitored optimizing neural-net',
#   83),
#  ('031-49-1357',
#   'Inverse optimizing neural-net',
#   '885-71-1570',
#   'Operative optimizing neural-net',
#   83),
#  ('031-51-5571',
#   'Team-oriented 3rdgeneration archive',
#   '563-03-6435',
#   'Team-oriented 3rdgeneration forecast',
#   85),
#  ('031-53-0600',
#   'Horizontal optimal process improvement',
#   '615-70-7903',
#   'Horizontal transitional process improvement',
#   86),
#  ('031-53-0600',
#   'Horizontal optimal process improvement',
#   '673-45-7198',
#   'Robust optimal process improvement',
#   83),
#  ('031-54-3741',
#   'Open-architected grid-enabled utilization',
#   '545-92-3284',
#   'Open-architected grid-enabled matrix',
#   86),
#  ('031-85-6729',
#   'Face-to-face solution-oriented secured line',
#   '653-33-4358',
#   'Face-to-face solution-oriented superstructure',
#   84),
#  ('032-38-9307',
#   'Assimilated neutral software',
#   '349-36-5132',
#   'Assimilated neutral database',
#   82),
#  ('032-82-0031',
#   'Versatile human-resource portal',
#   '660-74-9064',
#   'Versatile human-resource orchestration',
#   84),
#  ('032-82-0031',
#   'Versatile human-resource portal',
#   '779-48-4683',
#   'Up-sized human-resource portal',
#   82),
#  ('033-14-2328',
#   'Intuitive zero tolerance projection',
#   '269-89-3947',
#   'Digitized zero tolerance projection',
#   86),
#  ('033-14-2328',
#   'Intuitive zero tolerance projection',
#   '630-86-7024',
#   'Monitored zero tolerance project',
#   81),
#  ('033-18-9829',
#   'Optimized real-time flexibility',
#   '187-68-0875',
#   'Optimized real-time flexibility',
#   100),
#  ('033-31-1632',
#   'Profit-focused static secured line',
#   '125-17-1820',
#   'Profit-focused static encoding',
#   84),
#  ('033-45-4604',
#   'Seamless logistical solution',
#   '131-69-0972',
#   'Secured logistical solution',
#   84),
#  ('033-70-8052',
#   'Decentralized directional frame',
#   '186-58-7659',
#   'Decentralized bi-directional task-force',
#   83),
#  ('033-70-8052',
#   'Decentralized directional frame',
#   '292-98-0234',
#   'Decentralized bi-directional product',
#   81),
#  ('033-71-4504',
#   'Decentralized clear-thinking knowledge user',
#   '388-82-1492',
#   'Sharable clear-thinking knowledge user',
#   84),
#  ('033-73-5754',
#   'Fundamental hybrid Graphic Interface',
#   '034-44-6823',
#   'Phased hybrid Graphic Interface',
#   81),
#  ('033-73-5754',
#   'Fundamental hybrid Graphic Interface',
#   '092-55-0051',
#   'Fundamental client-driven Graphic Interface',
#   81),
#  ('033-80-3744',
#   'Mandatory neutral model',
#   '313-14-0809',
#   'Mandatory neutral methodology',
#   85),
#  ('033-80-3744',
#   'Mandatory neutral model',
#   '496-14-5959',
#   'Mandatory national model',
#   85),
#  ('033-80-5431',
#   'Persistent systematic leverage',
#   '765-28-0546',
#   'Persistent systematic adapter',
#   81),
#  ('033-94-6312',
#   'Cloned system-worthy project',
#   '127-04-8992',
#   'Focused system-worthy product',
#   81),
#  ('033-94-6312',
#   'Cloned system-worthy project',
#   '361-43-8736',
#   'Cloned system-worthy complexity',
#   81),
#  ('033-97-4825',
#   'Visionary needs-based workforce',
#   '816-11-7015',
#   'Polarized needs-based workforce',
#   81),
#  ('034-06-1192',
#   'Ameliorated analyzing workforce',
#   '470-06-1682',
#   'Ameliorated analyzing array',
#   83),
#  ('034-08-6691',
#   'Centralized object-oriented infrastructure',
#   '062-70-2777',
#   'Versatile object-oriented structure',
#   81),
#  ('034-08-6691',
#   'Centralized object-oriented infrastructure',
#   '341-92-7925',
#   'Open-source object-oriented infrastructure',
#   83),
#  ('034-08-6691',
#   'Centralized object-oriented infrastructure',
#   '433-14-1939',
#   'Customizable object-oriented infrastructure',
#   85),
#  ('034-57-8191',
#   'Self-enabling attitude-oriented time-frame',
#   '154-95-3269',
#   'Self-enabling attitude-oriented hub',
#   83),
#  ('034-57-8191',
#   'Self-enabling attitude-oriented time-frame',
#   '713-60-6763',
#   'Self-enabling attitude-oriented archive',
#   84),
#  ('034-58-9967',
#   'Adaptive heuristic analyzer',
#   '384-54-1180',
#   'Automated heuristic analyzer',
#   84),
#  ('034-84-6155',
#   'Reduced 6thgeneration projection',
#   '081-84-9939',
#   'Re-contextualized 6thgeneration projection',
#   81),
#  ('034-84-6155',
#   'Reduced 6thgeneration projection',
#   '105-39-3696',
#   'Reduced 5thgeneration application',
#   83),
#  ('034-84-6155',
#   'Reduced 6thgeneration projection',
#   '122-91-5715',
#   'Reduced 6thgeneration encryption',
#   88),
#  ('034-84-6155',
#   'Reduced 6thgeneration projection',
#   '300-93-5995',
#   'Reduced 4thgeneration function',
#   84),
#  ('034-90-1759',
#   'Automated optimizing open system',
#   '318-89-8218',
#   'Multi-tiered optimizing open system',
#   84),
#  ('034-98-9683',
#   'Triple-buffered hybrid array',
#   '865-16-2799',
#   'Triple-buffered asymmetric array',
#   83),
#  ('035-26-3757',
#   'Quality-focused intermediate archive',
#   '522-81-5044',
#   'Quality-focused interactive architecture',
#   82),
#  ('035-26-3757',
#   'Quality-focused intermediate archive',
#   '706-54-3598',
#   'Quality-focused intermediate secured line',
#   83),
#  ('035-26-3757',
#   'Quality-focused intermediate archive',
#   '753-07-2890',
#   'Quality-focused disintermediate software',
#   84),
#  ('035-26-3757',
#   'Quality-focused intermediate archive',
#   '755-61-0918',
#   'Quality-focused intermediate portal',
#   85),
#  ('035-43-2366',
#   'Managed well-modulated website',
#   '297-69-2023',
#   'Visionary well-modulated website',
#   81),
#  ('035-43-2366',
#   'Managed well-modulated website',
#   '330-49-5763',
#   'Fundamental well-modulated website',
#   81),
#  ('035-43-2366',
#   'Managed well-modulated website',
#   '643-27-3312',
#   'Managed well-modulated definition',
#   83),
#  ('035-64-0724',
#   'Seamless even-keeled info-mediaries',
#   '224-40-6609',
#   'Inverse even-keeled info-mediaries',
#   84),
#  ('035-65-5135',
#   'Robust transitional interface',
#   '560-05-5403',
#   'Robust transitional matrices',
#   84),
#  ('035-69-3590',
#   'Extended well-modulated intranet',
#   '743-37-6712',
#   'Extended well-modulated application',
#   81),
#  ('035-80-3293',
#   'Compatible exuding migration',
#   '250-77-6990',
#   'Compatible exuding moderator',
#   86),
#  ('035-80-3293',
#   'Compatible exuding migration',
#   '264-81-4259',
#   'Pre-emptive exuding migration',
#   81),
#  ('035-80-3293',
#   'Compatible exuding migration',
#   '864-40-8424',
#   'Compatible uniform migration',
#   82),
#  ('035-85-2301',
#   'Organized zero-defect instruction set',
#   '165-51-5157',
#   'Team-oriented zero-defect instruction set',
#   82),
#  ('035-85-2301',
#   'Organized zero-defect instruction set',
#   '408-33-5166',
#   'Centralized zero-defect instruction set',
#   89),
#  ('035-85-2301',
#   'Organized zero-defect instruction set',
#   '850-87-2410',
#   'Total zero-defect instruction set',
#   83),
#  ('035-91-8051',
#   'Ergonomic context-sensitive core',
#   '750-66-9883',
#   'Ergonomic context-sensitive orchestration',
#   85),
#  ('035-91-8051',
#   'Ergonomic context-sensitive core',
#   '882-60-0405',
#   'Ergonomic context-sensitive monitoring',
#   86),
#  ('035-93-2248',
#   'Automated multi-state infrastructure',
#   '037-82-5003',
#   'Managed multi-state infrastructure',
#   86),
#  ('035-93-2248',
#   'Automated multi-state infrastructure',
#   '659-96-4048',
#   'Sharable multi-state infrastructure',
#   82),
#  ('036-07-0026',
#   'Ameliorated multi-state encryption',
#   '071-01-4234',
#   'Reduced multi-state encryption',
#   81),
#  ('036-07-0026',
#   'Ameliorated multi-state encryption',
#   '287-19-7804',
#   'Reactive multi-state encryption',
#   83),
#  ('036-07-0026',
#   'Ameliorated multi-state encryption',
#   '361-11-9499',
#   'Secured multi-state encryption',
#   84),
#  ('036-07-0026',
#   'Ameliorated multi-state encryption',
#   '843-30-3526',
#   'Ameliorated multi-state monitoring',
#   82),
#  ('036-07-0392',
#   'Quality-focused stable software',
#   '032-67-4167',
#   'Quality-focused stable access',
#   83),
#  ('036-07-0392',
#   'Quality-focused stable software',
#   '753-07-2890',
#   'Quality-focused disintermediate software',
#   82),
#  ('036-07-0392',
#   'Quality-focused stable software',
#   '896-87-2013',
#   'Quality-focused stable analyzer',
#   81),
#  ('036-36-6930',
#   'Configurable zero-defect strategy',
#   '243-91-3403',
#   'Configurable zero-defect core',
#   87),
#  ('036-36-6930',
# ...
#   90),
#  ('080-58-3908',
#   'Programmable mission-critical leverage',
#   '536-03-1123',
#   'Organic mission-critical leverage',
#   82),
#  ('080-58-3908',
#   'Programmable mission-critical leverage',
#   '568-76-1635',
#   'Programmable mission-critical challenge',
#   88),
#  ('080-58-3908',
#   'Programmable mission-critical leverage',
#   '704-88-5072',
#   'Programmable mission-critical intranet',
#   87),
#  ('080-58-3908',
#   'Programmable mission-critical leverage',
#   '791-16-0782',
#   'Programmable mission-critical toolset',
#   85),
#  ('080-79-2385',
#   'Networked zero tolerance ability',
#   '233-01-8227',
#   'Networked zero tolerance website',
#   88),
#  ('081-10-5515',
#   'Centralized multi-tasking open system',
#   '484-41-6232',
#   'Organized multi-tasking open system',
#   89),
#  ('081-23-1421',
#   'Triple-buffered user-facing functionalities',
#   '733-17-7861',
#   'Triple-buffered exuding functionalities',
#   88),
#  ('081-23-1421',
#   'Triple-buffered user-facing functionalities',
#   '784-84-2570',
#   'Triple-buffered foreground functionalities',
#   82),
#  ('081-42-8245',
#   'Ergonomic full-range flexibility',
#   '724-92-0787',
#   'Ergonomic tangible flexibility',
#   84),
#  ('081-73-8380',
#   'Digitized disintermediate utilization',
#   '340-39-4164',
#   'Distributed disintermediate emulation',
#   81),
#  ('081-77-3577',
#   'Reverse-engineered stable contingency',
#   '100-06-5154',
#   'De-engineered scalable contingency',
#   85),
#  ('081-81-1448',
#   'Function-based client-driven info-mediaries',
#   '253-18-8459',
#   'Function-based multi-state info-mediaries',
#   81),
#  ('081-81-6869',
#   'Self-enabling methodical pricing structure',
#   '472-40-8928',
#   'Self-enabling eco-centric pricing structure',
#   85),
#  ('081-93-4376',
#   'Customer-focused motivating core',
#   '150-71-3276',
#   'Customer-focused motivating support',
#   90),
#  ('081-93-4376',
#   'Customer-focused motivating core',
#   '525-03-6876',
#   'Customer-focused motivating focus group',
#   85),
#  ('082-18-1449',
#   'Virtual system-worthy database',
#   '221-98-9320',
#   'Horizontal system-worthy database',
#   86),
#  ('082-34-1092',
#   'Face-to-face multi-state interface',
#   '688-49-8364',
#   'Open-source multi-state interface',
#   81),
#  ('082-38-0877',
#   'Reactive holistic artificial intelligence',
#   '181-13-2914',
#   'Organized heuristic artificial intelligence',
#   81),
#  ('082-38-0877',
#   'Reactive holistic artificial intelligence',
#   '191-66-6383',
#   'Operative logistical artificial intelligence',
#   87),
#  ('082-52-5741',
#   'Configurable full-range open system',
#   '874-55-7889',
#   'Upgradable full-range open system',
#   85),
#  ('082-55-4373',
#   'Future-proofed next generation customer loyalty',
#   '592-83-5065',
#   'Future-proofed next generation open system',
#   81),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '165-39-8115',
#   'Re-engineered contextually-based intranet',
#   83),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '234-30-7187',
#   'Phased contextually-based interface',
#   81),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '378-07-5910',
#   'Cloned contextually-based groupware',
#   84),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '719-45-4688',
#   'Diverse contextually-based intranet',
#   84),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '797-34-8837',
#   'Cloned contextually-based architecture',
#   83),
#  ('082-65-9493',
#   'Cloned contextually-based intranet',
#   '832-88-7652',
#   'Intuitive contextually-based intranet',
#   85),
#  ('082-69-6161',
#   'Enhanced zero tolerance frame',
#   '020-94-7820',
#   'Enhanced zero tolerance task-force',
#   86),
#  ('082-69-6161',
#   'Enhanced zero tolerance frame',
#   '375-79-0481',
#   'Enhanced zero tolerance extranet',
#   89),
#  ('082-73-2268',
#   'Integrated neutral array',
#   '174-59-8215',
#   'Integrated neutral analyzer',
#   86),
#  ('082-87-7576',
#   'Distributed systematic strategy',
#   '506-99-8490',
#   'Streamlined systematic strategy',
#   81),
#  ('082-92-1869',
#   'Customer-focused demand-driven time-frame',
#   '630-15-6166',
#   'Customer-focused demand-driven intranet',
#   88),
#  ('083-13-3629',
#   'Enterprise-wide didactic application',
#   '359-09-5214',
#   'Enterprise-wide didactic algorithm',
#   83),
#  ('083-34-6477',
#   'Synergistic mission-critical moratorium',
#   '894-24-0789',
#   'Synergistic mission-critical framework',
#   86),
#  ('083-55-3063',
#   'Streamlined homogeneous policy',
#   '553-84-6384',
#   'Streamlined homogeneous model',
#   88),
#  ('083-73-9496',
#   'Visionary 5thgeneration customer loyalty',
#   '070-45-6472',
#   'Profound 5thgeneration customer loyalty',
#   84),
#  ('083-77-0861',
#   'Synchronized attitude-oriented model',
#   '224-85-9520',
#   'Synchronized attitude-oriented secured line',
#   84),
#  ('083-77-0861',
#   'Synchronized attitude-oriented model',
#   '281-74-8939',
#   'Right-sized attitude-oriented model',
#   82),
#  ('083-81-9509',
#   'Extended reciprocal database',
#   '279-75-5325',
#   'Extended reciprocal frame',
#   83),
#  ('083-87-9559',
#   'Virtual 6thgeneration collaboration',
#   '070-58-6886',
#   'Virtual 6thgeneration encryption',
#   84),
#  ('083-94-5326',
#   'Upgradable eco-centric solution',
#   '458-05-8984',
#   'Upgradable eco-centric protocol',
#   84),
#  ('083-94-5326',
#   'Upgradable eco-centric solution',
#   '821-51-8459',
#   'Stand-alone eco-centric solution',
#   83),
#  ('084-41-0403',
#   'Distributed static leverage',
#   '567-27-3381',
#   'Distributed methodical leverage',
#   83),
#  ('084-57-9858',
#   'Progressive neutral software',
#   '859-71-8855',
#   'Progressive logistical software',
#   81),
#  ('084-61-4555',
#   'Digitized uniform flexibility',
#   '370-49-9435',
#   'Monitored uniform flexibility',
#   83),
#  ('084-66-4925',
#   'Digitized incremental Graphical User Interface',
#   '680-27-8240',
#   'Digitized exuding Graphical User Interface',
#   84),
#  ('084-97-1070',
#   'Customizable actuating software',
#   '030-97-8887',
#   'Customizable actuating data-warehouse',
#   82),
#  ('084-97-1070',
#   'Customizable actuating software',
#   '606-78-9896',
#   'Customizable radical software',
#   83),
#  ('085-01-4915',
#   'Horizontal cohesive concept',
#   '376-59-1346',
#   'Horizontal cohesive project',
#   85),
#  ('085-01-4915',
#   'Horizontal cohesive concept',
#   '444-25-5680',
#   'Horizontal cohesive forecast',
#   84),
#  ('085-06-8272',
#   'Mandatory user-facing implementation',
#   '398-69-9217',
#   'Extended user-facing implementation',
#   82),
#  ('085-23-4587',
#   'Synchronized radical Local Area Network',
#   '001-46-0081',
#   'Synchronized content-based Local Area Network',
#   81),
#  ('085-23-4587',
#   'Synchronized radical Local Area Network',
#   '239-98-7177',
#   'Synchronized neutral Local Area Network',
#   90),
#  ('085-25-2250',
#   'Compatible bi-directional hub',
#   '227-96-5383',
#   'Compatible directional array',
#   81),
#  ('085-25-2250',
#   'Compatible bi-directional hub',
#   '763-81-6600',
#   'Compatible bi-directional model',
#   87),
#  ('085-84-8411',
#   'Re-contextualized multi-state productivity',
#   '148-34-8782',
#   'Re-contextualized multi-state adapter',
#   81),
#  ('086-07-2794',
#   'Compatible web-enabled system engine',
#   '422-57-5514',
#   'Compatible bottom-line system engine',
#   81),
#  ('086-07-4506',
#   'Organized global orchestration',
#   '609-87-2201',
#   'Organic mobile orchestration',
#   83),
#  ('086-07-4506',
#   'Organized global orchestration',
#   '882-82-1865',
#   'Organized web-enabled orchestration',
#   83),
#  ('086-38-9625',
#   'Managed systematic moderator',
#   '526-85-2551',
#   'Managed holistic moderator',
#   81),
#  ('086-64-3683',
#   'Cloned homogeneous Internet solution',
#   '118-72-6258',
#   'Synchronized homogeneous Internet solution',
#   87),
#  ('086-64-3683',
#   'Cloned homogeneous Internet solution',
#   '553-42-6735',
#   'Cloned composite Internet solution',
#   83),
#  ('086-74-5987',
#   'Team-oriented eco-centric service-desk',
#   '461-44-0597',
#   'Team-oriented dynamic service-desk',
#   83),
#  ('086-85-9499',
#   'Centralized 3rdgeneration hardware',
#   '044-22-9228',
#   'Centralized 3rdgeneration data-warehouse',
#   84),
#  ('086-85-9499',
#   'Centralized 3rdgeneration hardware',
#   '274-67-1094',
#   'Centralized 3rdgeneration concept',
#   81),
#  ('087-10-7117',
#   'Programmable transitional groupware',
#   '854-73-9269',
#   'Programmable next generation groupware',
#   82),
#  ('087-17-4865',
#   'Intuitive demand-driven application',
#   '041-05-3683',
#   'Advanced demand-driven application',
#   81),
#  ('087-17-4865',
#   'Intuitive demand-driven application',
#   '787-80-1230',
#   'Automated demand-driven application',
#   83),
#  ('087-17-5625',
#   'Open-architected mobile moderator',
#   '518-63-8763',
#   'Open-architected impactful moderator',
#   84),
#  ('087-17-5625',
#   'Open-architected mobile moderator',
#   '556-57-0590',
#   'Open-architected web-enabled moderator',
#   85),
#  ('087-17-5625',
#   'Open-architected mobile moderator',
#   '587-53-2074',
#   'Open-architected full-range moderator',
#   83),
#  ('087-26-5839',
#   'Profit-focused contextually-based neural-net',
#   '343-91-4564',
#   'Profit-focused contextually-based monitoring',
#   84),
#  ('087-26-5839',
#   'Profit-focused contextually-based neural-net',
#   '523-53-6307',
#   'Front-line contextually-based neural-net',
#   83),
#  ('087-39-2076',
#   'Balanced systemic intranet',
#   '563-55-6688',
#   'Reactive systemic intranet',
#   81),
#  ('087-40-8326',
#   'Object-based foreground framework',
#   '654-71-0614',
#   'Object-based bifurcated framework',
#   82),
#  ('087-40-8326',
#   'Object-based foreground framework',
#   '795-99-8860',
#   'Object-based foreground moratorium',
#   84),
#  ('087-47-5011',
#   'Intuitive empowering pricing structure',
#   '231-39-2523',
#   'Networked empowering pricing structure',
#   82),
#  ('087-53-8719',
#   'Monitored national encryption',
#   '158-08-4631',
#   'Monitored dynamic encryption',
#   84),
#  ('087-53-8719',
#   'Monitored national encryption',
#   '242-66-9447',
#   'Total national encryption',
#   81),
#  ('087-53-8719',
#   'Monitored national encryption',
#   '785-64-9599',
#   'Multi-tiered national encryption',
#   85),
#  ('087-71-9869',
#   'Devolved bottom-line analyzer',
#   '093-71-3471',
#   'Devolved bottom-line neural-net',
#   83),
#  ('087-73-3741',
#   'Multi-tiered executive success',
#   '695-13-1622',
#   'Multi-tiered executive infrastructure',
#   81),
#  ('087-83-5834',
#   'Face-to-face object-oriented focus group',
#   '362-42-8649',
#   'Polarized object-oriented focus group',
#   81),
#  ('088-04-4502',
#   'Focused multi-tasking website',
#   '319-57-6401',
#   'Focused multi-tasking core',
#   84),
#  ('088-27-7616',
#   'Adaptive multi-state website',
#   '131-80-9938',
#   'Adaptive multi-state adapter',
#   82),
#  ('088-27-7616',
#   'Adaptive multi-state website',
#   '701-18-1720',
#   'Adaptive multi-state frame',
#   81),
#  ('088-41-7205',
#   'Fully-configurable static Graphical User Interface',
#   '154-72-3609',
#   'Fully-configurable hybrid Graphic Interface',
#   82),
#  ('088-41-7205',
#   'Fully-configurable static Graphical User Interface',
#   '156-10-9944',
#   'Fully-configurable system-worthy Graphical User Interface',
#   88),
#  ('088-41-7205',
#   'Fully-configurable static Graphical User Interface',
#   '362-17-8131',
#   'Fully-configurable systematic Graphic Interface',
#   89),
#  ('088-41-7205',
#   'Fully-configurable static Graphical User Interface',
#   '485-22-5837',
#   'Configurable radical Graphical User Interface',
#   84),
#  ('088-43-4817',
#   'Decentralized tangible Graphic Interface',
#   '175-36-2756',
#   'Decentralized modular Graphic Interface',
#   84),
#  ('088-43-4817',
#   'Decentralized tangible Graphic Interface',
#   '363-91-6416',
#   'Synergized intangible Graphic Interface',
#   84),
#  ('088-43-4817',
#   'Decentralized tangible Graphic Interface',
#   '463-49-0100',
#   'Decentralized clear-thinking Graphic Interface',
#   81),
#  ('088-43-4817',
#   'Decentralized tangible Graphic Interface',
#   '893-44-2295',
#   'Up-sized tangible Graphic Interface',
#   83),
#  ('088-48-1777',
#   'Programmable needs-based info-mediaries',
#   '476-28-0449',
#   'Programmable exuding info-mediaries',
#   81),
#  ('088-48-1777',
#   'Programmable needs-based info-mediaries',
#   '635-06-1155',
#   'Programmable executive info-mediaries',
#   82),
#  ('088-75-3836',
#   'Decentralized 24/7 capability',
#   '790-82-1675',
#   'Centralized 24hour capability',
#   83),
#  ('088-95-4827',
#   'Automated zero-defect conglomeration',
#   '674-59-9272',
#   'Multi-layered zero-defect conglomeration',
#   84),
#  ('089-07-9577',
#   'Integrated user-facing complexity',
#   '558-16-5065',
#   'Proactive user-facing complexity',
#   83),
#  ('089-17-3894',
#   'Inverse multi-tasking core',
#   '319-57-6401',
#   'Focused multi-tasking core',
#   81),
#  ('089-17-3894',
#   'Inverse multi-tasking core',
#   '404-44-3128',
#   'Inverse multi-tasking challenge',
#   84),
#  ('089-29-9452',
#   'Vision-oriented motivating throughput',
#   '477-07-1865',
#   'Vision-oriented radical throughput',
#   82),
#  ('089-29-9452',
#   'Vision-oriented motivating throughput',
#   '630-99-1357',
#   'Vision-oriented tertiary throughput',
#   83),
#  ('089-53-5033',
#   'Up-sized bottom-line encryption',
#   '651-77-6471',
#   'Up-sized bottom-line concept',
#   85),
#  ('089-71-1361',
#   'Organized well-modulated matrices',
#   '155-71-1843',
#   'Organic well-modulated matrices',
#   94),
#  ('089-71-1361',
#   'Organized well-modulated matrices',
#   '407-67-5668',
#   'Organized well-modulated structure',
#   87),
#  ('089-71-1361',
#   'Organized well-modulated matrices',
#   '832-37-3836',
#   'Organized well-modulated middleware',
#   85),
#  ('089-94-4999',
#   'Streamlined 4thgeneration ability',
#   '479-95-5995',
#   'Streamlined 4thgeneration capability',
#   96),
#  ('089-94-4999',
#   'Streamlined 4thgeneration ability',
#   '642-05-3281',
#   'Streamlined 6thgeneration matrix',
#   83),
#  ('089-95-3848',
#   'Sharable explicit alliance',
#   '402-61-7294',
#   'Programmable explicit alliance',
#   82),
#  ('090-13-8818',
#   'Reactive asymmetric intranet',
#   '563-55-6688',
#   'Reactive systemic intranet',
#   85),
#  ('090-33-0843',
#   'Universal radical alliance',
#   '706-60-9606',
#   'Universal radical solution',
#   81),
#  ('090-67-1354',
#   'Diverse intermediate Graphical User Interface',
#   '342-12-9175',
#   'Diverse 3rdgeneration Graphical User Interface',
#   84),
#  ('090-69-7044',
#   'Organic bandwidth-monitored installation',
#   '559-61-8910',
#   'Organic bandwidth-monitored projection',
#   82),
#  ('090-69-7044',
#   'Organic bandwidth-monitored installation',
#   '687-84-1509',
#   'Organic bandwidth-monitored policy',
#   81),
#  ('090-69-7044',
#   'Organic bandwidth-monitored installation',
#   '754-36-3169',
#   'Extended bandwidth-monitored installation',
#   84),
#  ('090-69-7044',
#   'Organic bandwidth-monitored installation',
#   '807-57-7693',
#   'Organic bandwidth-monitored functionalities',
#   82),
#  ('090-76-8986',
#   'Programmable incremental productivity',
#   '239-67-5113',
#   'Programmable regional productivity',
#   87),
#  ('091-50-6265',
#   'Virtual 5thgeneration utilization',
#   '037-13-1090',
#   'Extended 5thgeneration utilization',
#   81),
#  ('091-50-6265',
#   'Virtual 5thgeneration utilization',
#   '140-80-3321',
#   'Distributed 5thgeneration utilization',
#   83),
#  ('091-68-7467',
#   'Ameliorated object-oriented attitude',
#   '138-19-0512',
#   'Ameliorated object-oriented adapter',
#   87),
#  ('091-68-7467',
#   'Ameliorated object-oriented attitude',
#   '460-54-5531',
#   'De-engineered object-oriented attitude',
#   81),
#  ('091-68-7467',
#   'Ameliorated object-oriented attitude',
#   '821-79-5674',
#   'Ameliorated object-oriented secured line',
#   82),
#  ('091-71-0585',
#   'Polarized high-level pricing structure',
#   '664-65-4370',
#   'Seamless high-level pricing structure',
#   83),
#  ('091-71-0585',
#   'Polarized high-level pricing structure',
#   '809-53-2377',
#   'Profound high-level pricing structure',
#   85),
#  ('091-76-8357',
#   'Organized optimizing alliance',
#   '156-72-1569',
#   'Integrated optimizing alliance',
#   81),
#  ('091-81-1948',
#   'Multi-tiered static circuit',
#   '317-73-4760',
#   'Multi-tiered neutral circuit',
#   84),
#  ('091-81-1948',
#   'Multi-tiered static circuit',
#   '368-97-7242',
#   'Multi-tiered hybrid circuit',
#   81),
#  ('092-08-4800',
#   'Fully-configurable optimal website',
#   '382-30-8311',
#   'Fully-configurable optimal intranet',
#   87),
#  ('092-08-4800',
#   'Fully-configurable optimal website',
#   '684-01-0301',
#   'Fully-configurable high-level website',
#   82),
#  ...]
